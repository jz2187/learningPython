# %%
from twitter import Twitter, OAuth

t = Twitter(auth=OAuth('856608920072310784-zGEXz8UP8mEGBOtpnlO8IJUZPjyuFel','LcnYVJLCZYP8i3X2aE5ZniExzI92Bzw9VGSyqSay9AO1l','AfhhBC32n0suI7kGy4Llcc25Z','cuFqamCW7q2BHqzOVHFqYHteAuh2egvFMXJQgXRVgpVt4L4PIi'))

pythonTweets = t.search.tweets(q= "#python")
print(pythonTweets)
# Out:
# {'statuses': [{'lang': 'en', 'retweeted': False, 'in_reply_to_status_id_str': None, 'in_reply_to_status_id': None, 'coordinates': None, 'contributors': None, 'favorite_count': 0, 'entities': {'urls': [], 'user_mentions': [{'name': 'Terry Jones', 'indices': [36, 48], 'id': 320134516, 'screen_name': 'PythonJones', 'id_str': '320134516'}], 'symbols': [], 'hashtags': [{'indices': [130, 137], 'text': 'python'}]}, 'retweet_count': 0, 'geo': None, 'source': '<a href="http://dieversaries.com" rel="nofollow">Celebrate Dieversaries</a>', 'favorited': False, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'id_str': '880079102480236545', 'place': None, 'in_reply_to_screen_name': None, 'is_quote_status': False, 'text': 'Happy Centred Triangular Prime Day! @PythonJones Terry Jones is 27,541 days old today which is a Centred Triangular Prime number. #python', 'in_reply_to_user_id_str': None, 'created_at': 'Wed Jun 28 15:03:03 +0000 2017', 'truncated': False, 'id': 880079102480236545, 'in_reply_to_user_id': None, 'user': {'lang': 'en-gb', 'url': 'https://t.co/drfKx4iPYD', 'notifications': False, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'protected': False, 'contributors_enabled': False, 'default_profile_image': False, 'has_extended_profile': False, 'translator_type': 'none', 'entities': {'url': {'urls': [{'url': 'https://t.co/drfKx4iPYD', 'expanded_url': 'http://every1000.com', 'indices': [0, 23], 'display_url': 'every1000.com'}]}, 'description': {'urls': []}}, 'verified': False, 'followers_count': 40, 'location': 'Everywhere', 'geo_enabled': False, 'name': 'Every Day Counts', 'profile_use_background_image': True, 'profile_text_color': '333333', 'profile_sidebar_border_color': 'EEEEEE', 'id': 3309234509, 'is_translation_enabled': False, 'follow_request_sent': False, 'friends_count': 1, 'time_zone': 'UTC', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'following': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3309234509/1464088599', 'statuses_count': 1871, 'id_str': '3309234509', 'description': "When birthdays aren't enough", 'utc_offset': 0, 'favourites_count': 2, 'screen_name': 'every1000days', 'default_profile': False, 'profile_sidebar_fill_color': 'EFEFEF', 'listed_count': 8, 'created_at': 'Fri Jun 05 12:56:47 +0000 2015', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/735062330229305348/7jOUUFQh_normal.jpg', 'profile_background_color': '131516', 'profile_image_url': 'http://pbs.twimg.com/profile_images/735062330229305348/7jOUUFQh_normal.jpg', 'is_translator': False, 'profile_link_color': '009999', 'profile_background_tile': True}}, {'lang': 'en', 'retweeted': False, 'in_reply_to_status_id_str': None, 'in_reply_to_status_id': None, 'possibly_sensitive': False, 'coordinates': None, 'contributors': None, 'favorite_count': 0, 'entities': {'urls': [{'url': 'https://t.co/NGCb1TlbRu', 'expanded_url': 'https://twitter.com/i/web/status/880078729904443392', 'indices': [113, 136], 'display_url': 'twitter.com/i/web/status/8…'}], 'user_mentions': [], 'symbols': [], 'hashtags': [{'indices': [102, 109], 'text': 'Python'}]}, 'retweet_count': 0, 'geo': None, 'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>', 'favorited': False, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'id_str': '880079011271069698', 'place': None, 'in_reply_to_screen_name': None, 'is_quote_status': False, 'text': 'RT: AnalyticsVidhya: Get hands-on knowledge in spaCy - an advanced library for implementing NLP using #Python. … https://t.co/NGCb1TlbRu', 'in_reply_to_user_id_str': None, 'created_at': 'Wed Jun 28 15:02:42 +0000 2017', 'truncated': False, 'id': 880079011271069698, 'in_reply_to_user_id': None, 'user': {'lang': 'en', 'url': None, 'notifications': False, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'protected': False, 'contributors_enabled': False, 'default_p ...

# %%
from twitter import *

t = Twitter(auth=OAuth('856608920072310784-zGEXz8UP8mEGBOtpnlO8IJUZPjyuFel','LcnYVJLCZYP8i3X2aE5ZniExzI92Bzw9VGSyqSay9AO1l','AfhhBC32n0suI7kGy4Llcc25Z','cuFqamCW7q2BHqzOVHFqYHteAuh2egvFMXJQgXRVgpVt4L4PIi'))
statusUpdate = t.statuses.update(status='Hello, world!')
print(statusUpdate)
# Out:
# {'lang': 'en', 'retweeted': False, 'geo': None, 'in_reply_to_status_id': None, 'coordinates': None, 'contributors': None, 'favorite_count': 0, 'entities': {'urls': [], 'user_mentions': [], 'symbols': [], 'hashtags': []}, 'retweet_count': 0, 'favorited': False, 'source': '<a href="https://twitter.com/Jianing_Zhai" rel="nofollow">zJenny</a>', 'id': 880079404608569344, 'in_reply_to_screen_name': None, 'in_reply_to_status_id_str': None, 'is_quote_status': False, 'text': 'Hello, world!', 'id_str': '880079404608569344', 'created_at': 'Wed Jun 28 15:04:15 +0000 2017', 'truncated': False, 'place': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'user': {'lang': 'en', 'url': None, 'notifications': False, 'profile_background_image_url': None, 'protected': False, 'contributors_enabled': False, 'default_profile_image': True, 'has_extended_profile': False, 'translator_type': 'none', 'entities': {'description': {'urls': []}}, 'verified': False, 'followers_count': 0, 'location': '', 'geo_enabled': False, 'name': 'Jianing Zhai', 'profile_use_background_image': True, 'profile_text_color': '333333', 'profile_sidebar_border_color': 'C0DEED', 'id': 856608920072310784, 'is_translation_enabled': False, 'follow_request_sent': False, 'friends_count': 1, 'time_zone': None, 'profile_background_image_url_https': None, 'following': False, 'statuses_count': 1, 'id_str': '856608920072310784', 'description': '', 'utc_offset': None, 'favourites_count': 0, 'screen_name': 'Jianing_Zhai', 'default_profile': True, 'profile_sidebar_fill_color': 'DDEEF6', 'listed_count': 0, 'created_at': 'Mon Apr 24 20:40:56 +0000 2017', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_background_color': 'F5F8FA', 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'is_translator': False, 'profile_link_color': '1DA1F2', 'profile_background_tile': False}}

# %%
import json
from urllib.request import urlopen 

def getCountry(ipAddress):
    response = urlopen("http://freegeoip.net/json/"+ipAddress).read() \
            .decode('utf-8')
    responseJson = json.loads(response)
    return responseJson.get("country_code")

print(getCountry("50.78.253.58"))
# Out:
# US

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re
import json

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl)
    bs0bj = BeautifulSoup(html, "lxml")
    return bs0bj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))

def getHistoryIPs(pageUrl):
    pageUrl = pageUrl.replace("/wiki/","")
    historyUrl = "http://en.wikipedia.org/w/index.php?title="+pageUrl+"&action=history"
    print("hisroty url is:"+historyUrl)
    
    html = urlopen(historyUrl)
    bs0bj = BeautifulSoup(html, "lxml")
    
    ipAddresses = bs0bj.findAll("a", {"class":"mw-anonuserlink"})
    addressList = set()
    for ipAddress in ipAddresses:
        addressList.add(ipAddress.get_text())
    return addressList


def getCountry(ipAddress):
    try:
        response = urlopen("http://freegeoip.net/json/"+ipAddress).read().decode('utf-8')
    except HTTPError:
        return None
    responseJson = json.loads(response)
    return responseJson.get("country_code")

links = getLinks("/wiki/Python_(programming_language)")


while(len(links) > 0):
    for link in links:
        print("-------------------")
        historyIPs = getHistoryIPs(link.attrs["href"])
        for historyIP in historyIPs:
            
            country = getCountry(historyIP)
            if country is not None:
                print(historyIP+" is from "+country)
        
    newLink = links[random.randint(0, len(links)-1)].attrs["href"]
    links = getLinks(newLink)
# Out:
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# happy
# 202.53.87.74 is fromIN
# happy
# 162.247.124.52 is fromCA
# happy
# 113.162.8.249 is fromVN
# happy
# 2605:a601:e0c:6300:996d:68c0:fb03:af2c is fromUS
# happy
# 213.207.90.158 is fromNL
# happy
# 116.58.205.165 is fromBD
# happy
# 2607:fb90:5223:c275:0:17:a6be:ca01 is fromUS
# happy
# 213.55.95.160 is fromET
# happy
# 66.87.64.75 is fromUS
# happy
# 213.108.115.55 is fromPL
# happy
# 110.55.67.15 is fromPH
# happy
# 92.115.222.143 is fromMD
# happy
# 37.238.238.36 is fromIQ
# happy
# 223.230.96.108 is fromIN
# happy
# 43.252.233.5 is fromMY
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# happy
# 75.139.254.117 is fromUS
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# happy
# 185.134.216.130 is fromNL
# happy
# 117.55.241.54 is fromIN
# happy
# 186.26.115.185 is fromCR
# happy
# 89.233.168.1 is fromCZ
# happy
# 2405:204:3184:6ebb::26:c8ac is fromIN
# happy
# 31.76.48.140 is fromGB
# happy
# 170.65.218.6 is fromUS
# happy
# 66.210.1.198 is fromUS
# happy
# 43.251.173.4 is fromIN
# happy
# 2405:205:120c:1cd::283:10ac is fromIN
# happy
# 45.64.213.38 is fromIN
# happy
# 2a02:1810:b410:9a00:4123:a069:298d:988b is fromBE
# happy
# 2804:7f5:d080:8b15:f8e9:693d:1d3c:40d5 is fromBR
# happy
# 203.192.249.10 is fromIN
# happy
# 128.123.37.139 is fromUS
# happy
# 45.116.233.53 is fromPK
# happy
# 107.77.213.113 is fromUS
# happy
# 82.22.39.157 is fromGB
# happy
# 2405:205:1200:1e68::28b7:b0ac is fromIN
# happy
# 2405:205:a000:9aed:4a52:61e9:6358:800e is fromIN
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# happy
# 5.199.208.23 is fromRU
# happy
# 114.79.32.242 is fromID
# happy
# 176.60.44.112 is fromBY
# happy
# 178.208.206.244 is fromGI
# happy
# 140.177.205.223 is fromUS
# happy
# 197.239.7.126 is fromUG
# happy
# 79.186.27.201 is fromPL
# happy
# 15.203.233.84 is fromUS
# happy
# 94.118.222.35 is fromGB
# happy
# 188.146.23.38 is fromPL
# happy
# 111.92.130.14 is fromPK
# happy
# 107.107.62.0 is fromUS
# happy
# 2604:2000:b064:3300:6dd3:b07e:494d:c5cd is fromUS
# happy
# 2601:2:4d00:27b:7189:66f1:1135:7f00 is fromUS
# happy
# 83.244.156.56 is fromGB
# happy
# 194.181.240.192 is fromPL
# happy
# 152.231.35.89 is fromNI
# happy
# 2600:1004:b151:6515:1c2a:675b:bb28:2986 is fromUS
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# happy
# 2600:1700:10e0:b970:d0be:a8fd:b1c3:dbe4 is fromUS
# happy
# 2602:306:ce66:8e80:7cd1:f46:7a9d:5081 is fromUS
# happy
# 2602:306:ce6e:9420:9c11:f1e0:b219:bef0 is fromUS
# happy
# 208.71.62.32 is fromUS
# happy
# 115.99.103.167 is fromIN
# happy
# 213.207.90.158 is fromNL
# happy
# 82.69.43.178 is fromGB
# happy
# 119.14.57.12 is fromTW
# happy
# 212.214.188.194 is fromSE
# happy
# 31.52.140.173 is fromGB
# happy
# 184.66.250.224 is fromCA
# happy
# 2001:4998:effd:600:a84f:6f16:1ea6:3d9c is fromUS
# happy
# 141.5.2.12 is fromDE
# happy
# 86.161.75.120 is fromGB
# happy
# 117.244.103.222 is fromIN
# happy
# 173.95.183.16 is fromUS
# happy
# 118.200.185.145 is fromSG
# happy
# 99.236.6.160 is fromCA
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Procedural_programming&action=history
# happy
# 63.193.94.14 is fromUS
# happy
# 201.27.72.206 is fromBR
# happy
# 37.211.33.26 is fromQA
# happy
# 73.19.237.89 is fromUS
# happy
# 62.253.69.42 is fromGB
# happy
# 194.81.178.163 is fromGB
# happy
# 107.1.229.152 is fromUS
# happy
# 63.199.46.148 is fromUS
# happy
# 195.132.60.60 is fromFR
# happy
# 90.222.80.124 is fromGB
# happy
# 91.213.250.8 is fromSE
# happy
# 14.139.234.50 is fromIN
# happy
# 77.56.53.183 is fromCH
# happy
# 72.239.0.15 is fromUS
# happy
# 193.60.223.165 is fromGB
# happy
# 63.199.46.9 is fromUS
# happy
# 86.152.129.204 is fromGB
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Reflective_programming&action=history
# happy
# 212.96.25.37 is fromMZ
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Software_design&action=history
# happy
# 112.204.234.62 is fromPH
# happy
# 121.6.122.250 is fromSG
# happy
# 117.18.231.54 is fromBD
# happy
# 188.70.8.163 is fromKW
# happy
# 2607:fb90:47:304:66f7:3c96:489d:dcc6 is fromUS
# happy
# 31.61.139.126 is fromPL
# happy
# 2405:204:6109:8ace::bac:e8a4 is fromIN
# happy
# 2602:30a:c005:6140:811c:1f14:3cd6:33d6 is fromUS
# happy
# 106.70.251.236 is fromAU
# happy
# 2601:d:7f82:2c20:b501:4a23:160c:3de8 is fromUS
# happy
# 103.204.119.6 is fromIN
# happy
# 2601:641:1:60c:796b:a24b:47fe:c226 is fromUS
# happy
# 92.107.190.169 is fromCH
# happy
# 103.51.95.185 is fromIN
# happy
# 116.202.248.202 is fromIN
# happy
# 41.220.18.230 is fromZW
# happy
# 49.191.33.124 is fromAU
# happy
# 213.106.31.246 is fromGB
# happy
# 39.47.55.196 is fromPK
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# happy
# 67.171.73.105 is fromUS
# happy
# 184.153.183.139 is fromUS
# happy
# 87.228.157.89 is fromCY
# happy
# 204.14.15.229 is fromUS
# happy
# 192.240.74.175 is fromUS
# happy
# 2405:204:9002:f662:5302:b3f9:9a2b:13b9 is fromIN
# happy
# 195.148.173.220 is fromFI
# happy
# 2604:2000:eed4:7200:6419:8dc9:1176:27f5 is fromUS
# happy
# 99.228.87.7 is fromCA
# happy
# 108.45.29.72 is fromUS
# happy
# 194.53.210.44 is fromNL
# happy
# 2604:2000:eed4:7200:f12f:bfa6:5d52:3e7d is fromUS
# happy
# 111.164.216.251 is fromCN
# happy
# 117.196.232.127 is fromIN
# happy
# 2a02:c7d:9e2a:7800:85c3:9b5:7f8c:a731 is fromGB
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Software_developer&action=history
# happy
# 183.87.216.162 is fromIN
# happy
# 129.45.119.199 is fromDZ
# happy
# 82.229.30.79 is fromFR
# happy
# 94.67.166.168 is fromGR
# happy
# 180.81.77.88 is fromKR
# happy
# 185.88.24.27 is fromIQ
# happy
# 136.185.220.45 is fromIN
# happy
# 103.242.216.220 is fromBD
# happy
# 49.128.160.178 is fromIN
# happy
# 104.192.8.114 is fromUS
# happy
# 99.9.65.76 is fromUS
# happy
# 159.255.160.81 is fromIQ
# happy
# 58.114.190.8 is fromTW
# happy
# 202.136.88.107 is fromBD
# happy
# 98.102.66.2 is fromUS
# happy
# 168.184.255.90 is fromUS
# happy
# 174.255.140.1 is fromUS
# happy
# 216.48.140.24 is fromUS
# happy
# 101.223.36.32 is fromIN
# happy
# 119.30.45.131 is fromBD
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Python_Software_Foundation&action=history
# happy
# 50.56.228.68 is fromUS
# happy
# 119.15.154.71 is fromBD
# happy
# 70.198.36.48 is fromUS
# happy
# 70.198.33.152 is fromUS
# happy
# 194.83.198.199 is fromGB
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Software_release_life_cycle&action=history
# happy
# 41.113.177.148 is fromZA
# happy
# 98.127.68.175 is fromUS
# happy
# 2a02:c7d:26cb:4a00:d5a3:a750:525e:3c66 is fromGB
# happy
# 73.20.136.132 is fromUS
# happy
# 76.14.31.74 is fromUS
# happy
# 49.151.43.217 is fromPH
# happy
# 71.224.121.72 is fromUS
# happy
# 82.5.104.232 is fromGB
# happy
# 14.140.53.210 is fromIN
# happy
# 24.162.113.203 is fromUS
# happy
# 222.221.16.117 is fromCN
# happy
# 49.216.66.50 is fromTW
# happy
# 103.242.23.184 is fromBD
# happy
# 2405:204:4009:3b5b:5c7:db2e:4a4a:6f61 is fromIN
# happy
# 223.24.40.60 is fromTH
# happy
# 98.226.83.167 is fromUS
# happy
# 145.221.52.105 is fromNL
# happy
# 119.30.39.24 is fromBD
# happy
# 213.140.59.88 is fromDZ
# happy
# 1.54.212.134 is fromVN
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Type_system&action=history
# happy
# 211.100.57.47 is fromCN
# happy
# 174.21.122.167 is fromUS
# happy
# 192.55.2.36 is fromUS
# happy
# 81.204.49.200 is fromNL
# happy
# 76.191.222.78 is fromUS
# happy
# 84.173.153.20 is fromDE
# happy
# 61.68.220.194 is fromAU
# happy
# 206.169.223.194 is fromUS
# happy
# 213.108.115.55 is fromPL
# happy
# 70.247.167.70 is fromUS
# happy
# 115.114.69.98 is fromIN
# happy
# 2001:630:212:220:ea40:f2ff:fee2:360e is fromGB
# happy
# 86.190.245.99 is fromGB
# happy
# 98.113.211.12 is fromUS
# happy
# 2a01:79c:ceba:71d8:415d:5cc3:b77f:b884 is fromNO
# happy
# 47.18.143.110 is fromUS
# happy
# 107.77.164.31 is fromUS
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Duck_typing&action=history
# happy
# 2620:149:4:1c02:4424:4454:a038:4ac8 is fromUS
# happy
# 193.49.118.7 is fromFR
# happy
# 50.81.61.167 is fromUS
# happy
# 149.126.4.73 is fromCH
# happy
# 59.10.72.130 is fromKR
# happy
# 84.3.187.196 is fromHU
# happy
# 178.255.11.40 is fromEE
# happy
# 104.63.252.164 is fromUS
# happy
# 2001:4898:8010::343 is fromUS
# happy
# 190.60.115.135 is fromCO
# happy
# 2a00:79e0:d:107:28ba:af0b:b5fc:1064 is fromGB
# happy
# 83.31.45.80 is fromPL
# happy
# 193.140.54.250 is fromTR
# happy
# 94.61.69.117 is fromPT
# happy
# 92.62.8.1 is fromGB
# happy
# 73.216.44.168 is fromUS
# happy
# 199.19.253.13 is fromCA
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Dynamic_typing&action=history
# happy
# 192.102.214.6 is fromNL
# happy
# 172.194.101.14 is fromAU
# happy
# 24.217.36.41 is fromUS
# happy
# 62.23.212.160 is from
# happy
# 128.250.6.134 is fromAU
# happy
# 195.149.37.65 is fromGB
# happy
# 131.111.8.99 is fromGB
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Strong_typing&action=history
# happy
# 75.152.190.38 is fromCA
# happy
# 83.254.128.245 is fromSE
# happy
# 98.155.76.148 is fromUS
# happy
# 75.35.50.37 is fromUS
# happy
# 137.52.233.174 is fromUS
# happy
# 59.167.127.158 is fromAU
# happy
# 68.2.187.224 is fromUS
# happy
# 79.67.253.90 is fromGB
# happy
# 88.175.108.247 is fromFR
# happy
# 71.61.178.1 is fromUS
# happy
# 46.14.245.69 is fromCH
# happy
# 98.234.249.218 is fromUS
# happy
# 82.69.159.205 is fromGB
# happy
# 123.201.228.97 is fromIN
# happy
# 219.64.72.209 is fromIN
# happy
# 219.64.70.220 is fromIN
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Operating_system&action=history
# happy
# 176.62.142.129 is fromBE
# happy
# 2405:205:4003:e792::284f:d0ac is fromIN
# happy
# 80.30.25.130 is fromES
# happy
# 2405:204:830f:9c8c:61b4:753a:5b83:dfe4 is fromIN
# happy
# 111.88.83.60 is fromPK
# happy
# 2405:204:628b:d3b5::1720:c8a4 is fromIN
# happy
# 122.172.16.83 is fromIN
# happy
# 124.253.1.29 is fromIN
# happy
# 120.63.20.18 is fromIN
# happy
# 170.79.53.52 is fromBR
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Cross-platform&action=history
# happy
# 27.109.18.42 is fromIN
# happy
# 150.107.9.230 is fromIN
# happy
# 93.238.0.11 is fromDE
# happy
# 209.250.178.129 is fromCA
# happy
# 73.27.116.224 is fromUS
# happy
# 49.151.28.104 is fromPH
# happy
# 192.55.79.166 is fromIN
# happy
# 62.218.31.12 is fromAT
# happy
# 122.169.111.88 is fromIN
# happy
# 113.53.122.127 is fromTH
# happy
# 182.232.83.221 is fromTH
# happy
# 70.31.195.135 is fromCA
# happy
# 217.112.221.86 is fromUA
# happy
# 24.18.99.119 is fromUS
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Software_license&action=history
# happy
# 198.49.31.112 is fromUS
# happy
# 1.186.249.250 is fromIN
# happy
# 2405:204:e406:5b43:1f64:f3ab:9404:719c is fromIN
# happy
# 208.30.47.2 is fromUS
# happy
# 76.175.128.194 is fromUS
# happy
# 115.164.48.136 is fromMY
# happy
# 198.49.31.131 is fromUS
# happy
# 142.197.168.198 is fromUS
# happy
# 198.49.31.129 is fromUS
# happy
# 121.241.127.12 is fromIN
# happy
# 2600:1:c403:d2cb:b27f:e90b:a6f4:41fa is fromUS
# -------------------
# hisroty url is:http://en.wikipedia.org/w/index.php?title=Python_Software_Foundation_License&action=history
# happy
# 74.56.110.127 is fromCA
# happy
# 90.215.243.133 is fromGB
# happy
# 71.110.212.116 is fromUS
